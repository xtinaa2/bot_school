# %% [markdown]
# Данный чат бот помогает пользователю определиться с медиа для просмотра на основании трех показателей: любимого архитектурного стиля, предпочтительного типа медиа (книга, игра или фильм) и поджанра (по два на кажый тип медиа). Бот не останавливается из-за потенциальных ошибок ввода. Всего конечных сценариев 30.

# %%
import pandas as pd  #с помощью пандас импортируем таблицу со всеми возможными конечными ответами 
knigi = pd.DataFrame({'Классицизм': ['"Архитектура русского классицизма в эпоху Екатерины Великой" Швидковский Дмитрий Олегович, John Summerson. «The Classical Language of Architecture»', '"Недоросль" Фонвизин, "Война и мир" Толстой'],'Модернизм': ['"Архитектура эпохи модерна: концепции, направления, мастера." Василий Семенович Горюнов, Михаил Павлович Тубли.', 'Скотт Вестерфельд «Левиафан»'],'Готика': ['"Gothic Architecture Improved by Rules and Proportions" Batty Langley, Thomas Langley', '"Собор Парижской Богоматери" В.М.Гюго, "Призрак оперы" Гастон Леру'],'Брутализм': ['Atlas of Brutalist Architecture', '"Кысь" Татьяна Толстая'],'Эко-брутализм': ['К сожалению, такого материала еще не написали.', '"Дюна" Фрэнк Герберт']})
games = pd.DataFrame({'Классицизм': ['Assassin`s Creed: Syndicate', 'Sherlock Holmes: Crimes and Punishments, Raven, The book of unwritten tales '],'Модернизм': ['Название', 'MACHINARIUM, FINAL FANTASY VI, Syberia'],'Готика': ['Gothic, Elden Ring', 'Amnesia: The Dark Descent'],'Брутализм': ['Desmond`s Journey', 'Kairo, NaissanceE'],'Эко-брутализм': ['Atomic Heart, Horizon Zero Dawn', 'Last of Us, Athanasy']})
movies = pd.DataFrame({'Классицизм': ['Война и Мир', 'Наполеон: Путь императора'],'Модернизм': ['Неистовые модернисты', 'Мой дядушка'],'Готика': ['Собор у моря', 'Сумерки'],'Брутализм': ['Ле Корбюзье. Гений и злодей архитектуры', 'Голова-Ластик'],'Эко-брутализм': ['Битва за Чернобыль (2006)',"'Эрго-прокси', 'Евангелион', 'Хроники хищных городов'"]})
arch = {1:'Классицизм', 2:'Модернизм', 3:'Готика', 4:'Брутализм', 5:'Эко-брутализм'} #словарь архитектурных стилей
info=str('Коротко о каждом стиле:\n1. Классицизм: архитектурный стиль, получивший распространение в XVII -IX веках. Характерные черты: стремление к ясности и простоте, симметрия, рациональные пропорции. Известнейшими памятниками классицизма в России являются работы Карла Росси в Санкт-Петербурге.\n2. Модернизм: истоки данного стиля зародились в конце IX столетия. Основные идеи: отказ от украшательств, упор на функционал, использование самых современных строительных материалов. Не то же самое, что модерн.\n3. Готика: архитектура позднего Средневековья, знаменита стрельчатыми арками, высокими сводами, сочетанием воздушности и внушительных размеров. Родина готики – Франция.\n4. Брутализм: это подвид модерного архитектурного стиля, чьими отличительными особенностями являются: строгость форм, акцент на материалы, текстуры и конструкцию, создающую очень выразительные формы.\n5. Эко-брутализм: развивающаяся концепция «постапокалиптического» брутализма. Подвид модернизма. Заброшенные строение брутализма начинают обрастать плющом и другими растениями. Архитектурный стиль пост-апокалипсиса.')

print('Привет! Я бот Niche, который помогает выбрать медиа в зависимости от предпочтений в архитектуре и медиа!')
name = str(input('Пожалуйста, введи свое имя!')) #сохраняем имя в переменной
print ('Приятно познакомиться,', name + ',')
print ('Вот список доступных архитектурных стилей:\n1. Классицизм\n2. Модернизм\n3. Готика\n4. Брутализм\n5. Эко-брутализм') #стили  указаны в столбик и пронумерованы 
print('Ты можешь сразу перейти к выбору или прочитать описание каждого стиля.') #предлагаем пользователю на выбор два сценария
cond = 0
while cond == 0:  #бот ждет пока пользователь введет 1 или 2
    try:
        grad = int(input('Введи 1, если хочешь сразу перейти к выбору, или 2 - если хочешь подробнее узнать об архетиктурных стилях.')) #в переменной grad будут храниться ответ 1 или 2
    except:
        print('Что-то пошло не так. Введи, пожалуйста, цифру 1 или цифру 2.')
        continue
    if grad == 2 or grad == 1:
        cond = 1
        break
    else:
        print('Что-то пошло не так. Введи, пожалуйста, цифру 1 или цифру 2.')
if grad == 2:
      print(info)   #бот выдает информацию про архитектурные стили стили
else: #если пользователь сразу переходит к выбору стиля
    print('Отлично! Спасибо,', name + '.')
print('Пожалуйста, выбери один интересующий тебя архитектурный стиль.')
cond = 0
while cond == 0: #проверяем что пользователь вводит одну цифру от 1 до 5 
    try:
        style = int(input("Введи порядковый номер стиля, например: 1")) #в переменной style будут храниться типы стилей
    except:
        print('Что-то пошло не так. Введи, пожалуйста, одну цифру: 1, 2, 3, 4 или 5.')
        continue
    if style in arch.keys():      #проверяем сходится ли значение со словарем
        cond = 1
        break
    else:
        print('Что-то пошло не так. Введи, пожалуйста, одну цифру: 1, 2, 3, 4 или 5.')
if style == 1:
    print(name+ ', скорее всего, ты любишь надежность и эстетику dark academia. Спасибо за выбор классицизма.') #бот подтверждает выбор пользователя и дает небольшой комментарий
elif style == 2:
    print(name+ ', ты либо любитель эффектного (и эффективного) минимализма, либо фанат дримкора. Спасибо за выбор модерна.')
elif style == 3:
    print(name+ ', ты не боишься показаться предсказуемым, у тебя хороший вкус и большой выбор медиа. Спасибо за выбор готики.')
elif style == 4:
    print(name+ ', я тоже люблю эстетику голого бетона. Спасибо за выбор брутализма.')
elif style == 5:
    print(name+ ', ты любишь контрасты и гоблинкор? Спасибо за выбор эко-брутализма.')
else:
    print('Отлично! Спасибо,', name + '.')
print(name + ', пожалуйста, выбери вид медиа: книга, игра или фильм, ты можешь выбрать несколько вариантов сразу.')
cond = 0 #счетчик, который нужен для прекращения цикла
while cond == 0:
    try:
        typ = list(map(int, input('Для этого введи следующие цифры:\n книга: 1\n игра: 2\n фильм: 3\nТы можешь ввести сразу две или три цифры, но введи их через запятую, пожалуйста, в порядке возрастания (например: 1,3).').split(','))) #в перемеенной typ хранится тип медиа
    except:
        print('Что-то пошло не так. Введи, пожалуйста, цифры 1, 2 или 3 через запятую в порядке возрастания.')
        continue
    if typ == [1,3] or typ == [2,3] or typ == [1,2] or typ == [1,2,3] or typ == [1] or typ == [2] or typ == [3]: #все корректные варианты набора 
        cond = 1
        break
    else:
        print('Что-то пошло не так. Введи, пожалуйста, цифры 1,2 или 3 через запятую в порядке возрастания.')
        continue
if typ == [1]:
    print('Ты выбрал_а книгу.') #бот подтверждает выбор пользователя
elif typ == [2]:
    print('Ты выбрал_а игру.')
elif typ == [3]:
    print('Ты выбрал_а фильм.')
elif typ == [1,2]:
    print('Ты выбрал_а книгу и игру.')
elif typ == [1,3]:
    print('Ты выбрал_а книгу и фильм.')
elif typ == [2,3]:
    print('Ты выбрал_а игру и фильм.')
elif typ == [1,2,3]:
    print('Ты выбрал_а  книгу, игру и фильм.')
else:
    print('Отлично! Спасибо,', name + '.')
print('Остался последний вопрос и я смогу дать тебе рекомендацию. Пожалуйста, выбери предпочтительный поджанр медиа.') #бот объясняет следующий шаг
if 1 in typ:  #узнаем про любимый вид книг
    cond = 0
    while cond == 0:
        try:
            bookgenre = int(input('Введи 1 для научной книги, 2 - для художественной.')) #в переменной bookgenre хранится тип книги
        except:
            print('Что-то пошло не так. Введи, пожалуйста, цифру 1 или цифру 2.')
            continue
        if bookgenre == 1 or bookgenre ==2:
            cond = 1
            print('Советую тебе прочитать', knigi.loc[(bookgenre-1), arch[style]])
            break
        else:
            print('Что-то пошло не так. Введи, пожалуйста, цифру 1 или цифру 2.')
if 2 in typ: #узнаем про любимый вид игр
    cond = 0
    while cond == 0:
        try:
            gamegenre = int(input('Введи 1 для игр с открытым миром, 2 - для всех остальных игр.')) #в переменной gamegenre хранится тип игры
        except:
            print('Что-то пошло не так. Введи, пожалуйста, цифру 1 или цифру 2.')
            continue
        if gamegenre == 1 or gamegenre ==2:
            cond = 1
            print('Советую тебе поиграть в', games.loc[(gamegenre-1), arch[style]])
            break
        else:
            print('Что-то пошло не так. Введи, пожалуйста, цифру 1 или цифру 2.')
if 3 in typ:   #узнаем про любимый вид фильмов
    cond = 0
    while cond == 0:
        try:
            moviegenre = int(input('Введи 1 для документального фильма, 2 - для художественного фильма.')) #в переменной moviegenre хранится тип фильма
        except:
            print('Что-то пошло не так. Введи, пожалуйста, цифру 1 или цифру 2.')
            continue
        if moviegenre == 1 or moviegenre ==2:
            cond = 1
            print('Советую тебе посмотреть', movies.loc[(moviegenre-1), arch[style]])
            break
        else:
            print('Что-то пошло не так. Введи, пожалуйста, цифру 1 или цифру 2.')
print(name+ ', ты удовлетворен_а моей рекомендацией?')
cond = 0
while cond == 0:
    try:
        answer = input('Пожалуйста, напиши "да" или "нет".') #в перемеенной ans хранится ответ пользователя
    except:
        print('Я тебя не понимаю. Напиши, пожалуйста, "да" или "нет".')
        continue
    if answer == 'да' or answer == 'нет' or answer == 'yes' or answer == 'no': #все корректные варианты набора 
        cond = 1
        break
    else:
        print('Я тебя не понимаю. Напиши, пожалуйста, "да" или "нет".')
        continue
if answer == 'да' or answer == 'yes':
    print('Спасибо за ответ! Рад был помочь.')
else:
    rec=input('Пожалуйста, напиши, что тебе не понравилось и что можно улучшить')
    print('Твой ответ:', rec, ' Спасибо,', name + '!')

# %% [markdown]
# В коде использована функция "try-except", которая перехватывает исключения (например неправильный формат вводимых данных или синтаксическая ошибка). Эта функция зациклена, чтобы также проверять соответствие значений, вводимых пользователем, необходимым. Ниже документация и пример использования этой функции:

# %%
def exceptions ('try, except, finally')
                        блок try позволяет проверить блок кода на ошибки
                        блок except позволяет отреагировать на ошибку
                        блок else позволяет провести код, если ошибки нет
                        блок finally позволяет провести код в любом из сценариев в except и else

# %%
cond = 0
while cond == 0: #проверяем что пользователь вводит одну цифру от 1 до 5 
    try:
        style = int(input('Пожалуйста, выбери, один интересующий тебя стиль, набрав его порядковый номер на клавиатуре')) #в переменной style будут храниться типы стилей
    except:
        print('Что-то пошло не так. Введи, пожалуйста, одну цифру: 1, 2, 3, 4 или 5')
        continue
    if style in arch.keys():      #проверяем сходится ли значение со словарем
        cond = 1
        break
    else:
        print('Что-то пошло не так. Введи, пожалуйста, одну цифру: 1, 2, 3, 4 или 5')
